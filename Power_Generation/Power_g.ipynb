# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('D:/Datasets/PowerGeneration.csv')

# %%
data.head(5)
# Out:
#          Date Power Station  Monitored Cap.(MW)  \
# 0  01-09-2017         Delhi              2235.4
# 1  01-09-2017          STPL              1350.0
# 2  01-09-2017          SPPL               150.0
# 3  01-09-2017           SPL              3960.0
# 4  01-09-2017           SKS               600.0
#
#    Total Cap. Under Maintenace (MW)  Planned Maintanence (MW)  \
# 0                             135.0                       0.0
# 1                            1350.0                       0.0
# 2                             150.0                       0.0
# 3                               0.0                       0.0
# 4                             300.0                       0.0
#
#    Forced Maintanence(MW)  Other Reasons (MW)  Programme (MW)  Actual (MW)  \
# 0                   135.0                 0.0           13.29        18.29
# 1                  1350.0                 0.0            0.00         0.00
# ...

# %%
data['Power Station'].unique()
# Out:
# array(['Delhi', 'STPL', 'SPPL', 'SPL', 'SKS', 'SCPL', 'RKMPPL', 'RGPPL',
#        'SVPPL', 'RELIANCE', 'RATTANINDIA', 'PGPL', 'NTPC Ltd.', 'NSPCL',
#        'NPCIL', 'NHDC', 'MCCPL', 'REGL', 'MBPMPL', 'TATA MAH.',
#        'TOR. POW. (SUGEN)', 'BSES  AP', 'BELLARY', 'APGPCL', 'ABAN POWR',
#        'Telangana', 'Tamil Nadu', 'Puducherry', 'TATA PCL', 'Kerala',
#        'Andhra Pradesh', 'WPCL', 'VVL', 'VIP', 'VESPL', 'TRNE',
#        'TOR. POW. (UNOSUGEN)', 'Karnataka', 'LVTPL', 'LANCO', 'JSWEL',
#        'ACPL', 'ACB', 'Maharashtra', 'Madhya Pradesh', 'Gujarat',
#        'Chhatisgarh', 'TSPL', 'AEML', 'TPDDL', 'SrEPL', 'SJVNL',
#        'RWPL (JSW)', 'RPSCL', 'PPGCL (Jaypee)', 'NUPPL', 'THDC', 'AMNEPL',
#        'APL', 'BALCO', 'JPPVL', 'JPL', 'JHAPL', 'IEPL', 'GMR ENERG',
#        'GIPCL', 'GEPL', 'GCEL', 'ESSARPMPL', 'ESSAR', 'EPGL', 'DLHP',
#        'DIL', 'DBPCL', 'CLPINDIA', 'CGPL', 'BLAPPL', 'BSES(C)', 'CEPL',
# ...

# %%
data['Power Station'].nunique()
# Out:
# 182

# %%
data.isnull().sum()
# Out:
# Date                                0
# Power Station                       0
# Monitored Cap.(MW)                  0
# Total Cap. Under Maintenace (MW)    0
# Planned Maintanence (MW)            0
# Forced Maintanence(MW)              0
# Other Reasons (MW)                  0
# Programme (MW)                      0
# Actual (MW)                         0
# Excess(+) / Shortfall (-) (MW)      0
# Deviation (MW)                      0
# dtype: int64

# %%
data.dtypes
# Out:
# Date                                 object
# Power Station                        object
# Monitored Cap.(MW)                  float64
# Total Cap. Under Maintenace (MW)    float64
# Planned Maintanence (MW)            float64
# Forced Maintanence(MW)              float64
# Other Reasons (MW)                  float64
# Programme (MW)                      float64
# Actual (MW)                         float64
# Excess(+) / Shortfall (-) (MW)      float64
# Deviation (MW)                      float64
# dtype: object

# %%
data = data.drop('Date', axis = 1)

# %%
data
# Out:
#        Power Station  Monitored Cap.(MW)  Total Cap. Under Maintenace (MW)  \
# 0              Delhi              2235.4                             135.0
# 1               STPL              1350.0                            1350.0
# 2               SPPL               150.0                             150.0
# 3                SPL              3960.0                               0.0
# 4                SKS               600.0                             300.0
# ...              ...                 ...                               ...
# 334989      TATA PCL              1430.0                             500.0
# 334990     TATA MAH.               447.0                               0.0
# 334991         SVPPL                63.0                               0.0
# 334992       BELLARY                25.2                               0.0
# 334993          ONGC               726.6                               0.0
#
# ...

# %%
data['Power Station'].value_counts().sort_values()
# Out:
# IEL                 165
# TPCIL               171
# DPSCLTD             189
# PVUNL               203
# Andhra Pradesh.     320
#                    ...
# TATA PCL           3730
# NPCIL              5577
# NHPC               5577
# GMR ENERG          5593
# NTPC Ltd.          9295
# Name: Power Station, Length: 182, dtype: int64

# %%
data.groupby('Power Station').sum().sort_values(by=['Monitored Cap.(MW)'], ascending= False)
# Out:
#                Monitored Cap.(MW)  Total Cap. Under Maintenace (MW)  \
# Power Station
# NTPC Ltd.             90864945.57                       20402335.63
# Maharashtra           24672070.00                        6350635.00
# Gujarat               17596730.70                        7038500.39
# APL                   17224680.00                        4793910.00
# Karnataka             16398987.32                        6390895.30
# ...                           ...                               ...
# LVTPL                        0.00                              0.00
# DPSCLTD                      0.00                              0.00
# LBPL                         0.00                              0.00
# BIPL                         0.00                              0.00
# NUPPL                        0.00                              0.00
#
#                Planned Maintanence (MW)  Forced Maintanence(MW)  \
# Power Station
# ...

# %%
data.groupby('Power Station').sum().sort_values(by=['Monitored Cap.(MW)'], ascending=False).head(15)
# Out:
#                 Monitored Cap.(MW)  Total Cap. Under Maintenace (MW)  \
# Power Station
# NTPC Ltd.              90864945.57                       20402335.63
# Maharashtra            24672070.00                        6350635.00
# Gujarat                17596730.70                        7038500.39
# APL                    17224680.00                        4793910.00
# Karnataka              16398987.32                        6390895.30
# Rajasthan              14741876.00                        5369883.80
# Telangana              13484808.50                        2663725.30
# DVC                    13250118.00                        3108826.40
# Tamil Nadu             13229422.80                        3725515.03
# NPCIL                  12418120.00                        2972940.00
# West Bengal            11963670.00                        3193403.50
# Uttar Pradesh          11540567.00                        3115052.20
# ...

# %%
data.groupby('Power Station').sum().sort_values(by=['Excess(+) / Shortfall (-) (MW)'], ascending=False).head(15)
# Out:
#                 Monitored Cap.(MW)  Total Cap. Under Maintenace (MW)  \
# Power Station
# NTPC Ltd.              90864945.57                       20402335.63
# GCEL                    2553680.00                         961740.00
# JPL                     6334200.00                        3110550.00
# DVC                    13250118.00                        3108826.40
# SPL                     7361640.00                         566940.00
# West Bengal            11963670.00                        3193403.50
# Kerala                  3801598.64                         715170.90
# JITPL                   2230800.00                         739200.00
# DIL                      433200.00                          18000.00
# SGPL                     583440.00                          33660.00
# DIPL                     682200.00                         141000.00
# JPPVL                   4126980.00                         472800.00
# ...

# %%
data.groupby('Power Station').sum().sort_values(by=['Forced Maintanence(MW)'], ascending=False).head(15)
# Out:
#                 Monitored Cap.(MW)  Total Cap. Under Maintenace (MW)  \
# Power Station
# NTPC Ltd.              90864945.57                       20402335.63
# Karnataka              16398987.32                        6390895.30
# Maharashtra            24672070.00                        6350635.00
# Gujarat                17596730.70                        7038500.39
# Rajasthan              14741876.00                        5369883.80
# APL                    17224680.00                        4793910.00
# JPL                     6334200.00                        3110550.00
# West Bengal            11963670.00                        3193403.50
# Madhya Pradesh         10922995.00                        3634988.00
# Punjab                  5557098.50                        2917457.85
# Haryana                 4909280.00                        2518120.00
# DVC                    13250118.00                        3108826.40
# ...

# %%
sns.lineplot(data=data, x='Power Station', y='Monitored Cap.(MW)')
# Out:
# <Axes: xlabel='Power Station', ylabel='Monitored Cap.(MW)'>

# %%
data.groupby('Power Station').sem()
# Out:
#                Monitored Cap.(MW)  Total Cap. Under Maintenace (MW)  \
# Power Station
# 0                       42.156087                         11.551438
# ABAN POWR                0.000020                          1.177762
# ACB                      0.000000                          2.086983
# ACPL                     0.000000                          0.000000
# ADHPL                    0.000000                          1.366745
# ...                           ...                               ...
# VESPL                    0.000000                          0.000000
# VIP                      0.000000                          4.872924
# VVL                      0.000000                          0.000000
# WPCL                     3.625614                         12.479648
# West Bengal              4.986228                         16.380355
#
#                Planned Maintanence (MW)  Forced Maintanence(MW)  \
# Power Station
# ...

# %%
data.groupby('Power Station').sem().max()
# Out:
# Monitored Cap.(MW)                  59.958252
# Total Cap. Under Maintenace (MW)    44.232504
# Planned Maintanence (MW)            23.525187
# Forced Maintanence(MW)              33.785125
# Other Reasons (MW)                  14.727821
# Programme (MW)                       0.947735
# Actual (MW)                          1.040713
# Excess(+) / Shortfall (-) (MW)       1.037852
# Deviation (MW)                       9.227360
# dtype: float64

# %%
sns.barplot(data=data, x='Power Station', y='Actual (MW)')
# Out:
# <Axes: xlabel='Power Station', ylabel='Actual (MW)'>

# %%
X = data.drop(labels='Actual (MW)', axis = 1)
y = data.iloc[:,7]

# %%
X
# Out:
#        Power Station  Monitored Cap.(MW)  Total Cap. Under Maintenace (MW)  \
# 0              Delhi              2235.4                             135.0
# 1               STPL              1350.0                            1350.0
# 2               SPPL               150.0                             150.0
# 3                SPL              3960.0                               0.0
# 4                SKS               600.0                             300.0
# ...              ...                 ...                               ...
# 334989      TATA PCL              1430.0                             500.0
# 334990     TATA MAH.               447.0                               0.0
# 334991         SVPPL                63.0                               0.0
# 334992       BELLARY                25.2                               0.0
# 334993          ONGC               726.6                               0.0
#
# ...

# %%
y
# Out:
# 0         18.29
# 1          0.00
# 2          0.00
# 3         96.16
# 4          7.18
#           ...
# 334989    16.98
# 334990     3.96
# 334991     1.22
# 334992     0.00
# 334993    14.56
# Name: Actual (MW), Length: 334994, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size= 0.2, random_state= 1)

# %%
X_train.reset_index(drop = True, inplace = True)

# %%
X_train
# Out:
#        Power Station  Monitored Cap.(MW)  Total Cap. Under Maintenace (MW)  \
# 0        Chhatisgarh              3200.0                             580.0
# 1              LVTPL                 0.0                               0.0
# 2           JhPL(HR)              1320.0                             660.0
# 3                HEL               600.0                               0.0
# 4               CEPL              1200.0                             600.0
# ...              ...                 ...                               ...
# 267990          WPCL              2340.0                             270.0
# 267991          ONGC               726.6                               0.0
# 267992         ADHPL               192.0                               0.0
# 267993     Meghalaya               322.0                               0.0
# 267994           SKS               600.0                             600.0
#
# ...

# %%
X_train.isnull().sum()
# Out:
# Power Station                       0
# Monitored Cap.(MW)                  0
# Total Cap. Under Maintenace (MW)    0
# Planned Maintanence (MW)            0
# Forced Maintanence(MW)              0
# Other Reasons (MW)                  0
# Programme (MW)                      0
# Excess(+) / Shortfall (-) (MW)      0
# Deviation (MW)                      0
# dtype: int64

# %%
X_train.drop(labels='Power Station', axis = 1, inplace = True)

# %%
X_train
# Out:
#         Monitored Cap.(MW)  Total Cap. Under Maintenace (MW)  \
# 0                   3200.0                             580.0
# 1                      0.0                               0.0
# 2                   1320.0                             660.0
# 3                    600.0                               0.0
# 4                   1200.0                             600.0
# ...                    ...                               ...
# 267990              2340.0                             270.0
# 267991               726.6                               0.0
# 267992               192.0                               0.0
# 267993               322.0                               0.0
# 267994               600.0                             600.0
#
#         Planned Maintanence (MW)  Forced Maintanence(MW)  Other Reasons (MW)  \
# 0                          250.0                   330.0                 0.0
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()

# %%
X_train = ss.fit_transform(X_train)

# %%
X_train = pd.DataFrame(X_train, columns=['Monitored Cap.(MW)','Total Cap. Under Maintenace(MW)','Planned Maintanence(MW)','Forced Maintanence(MW)','Other Reasons(MW)','Programme(MW)','Excess(+) / Shortfall(-)(MW)','Deviation(MW)'])

# %%
X_train
# Out:
#         Monitored Cap.(MW)  Total Cap. Under Maintenace(MW)  \
# 0                 0.617799                         0.125725
# 1                -0.604598                        -0.566234
# 2                -0.100359                         0.221168
# 3                -0.375399                        -0.566234
# 4                -0.146199                         0.149586
# ...                    ...                              ...
# 267990            0.289280                        -0.244115
# 267991           -0.327038                        -0.566234
# 267992           -0.531254                        -0.566234
# 267993           -0.481594                        -0.566234
# 267994           -0.375399                         0.149586
#
#         Planned Maintanence(MW)  Forced Maintanence(MW)  Other Reasons(MW)  \
# 0                      0.891624                0.037741           -0.35917
# 1                     -0.321430               -0.467958           -0.35917
# ...

# %%
y_train.reset_index(drop=True, inplace= True)

# %%
X_test.reset_index(drop= True, inplace= True)
X_test = X_test.drop(['Power Station'], axis=1)
X_test = ss.fit_transform(X_test, y_test)
X_test = pd.DataFrame(X_test, columns=['Monitored Cap.(MW)', 'Total Cap. Under Maintenace(MW)', 'Planned Maintanence(MW)','Forced Maintanence(MW)', 'Other Reasons(MW)', 'Programme(MW)', 'Excess(+) / Shortfall(-)(MW)', 'Deviation(MW)'])

# %%
y_test.reset_index(drop= True, inplace= True)

# %%
X_test
# Out:
#        Monitored Cap.(MW)  Total Cap. Under Maintenace(MW)  \
# 0               -0.559368                        -0.503328
# 1               -0.578974                        -0.562490
# 2               -0.370845                        -0.562490
# 3                0.172653                        -0.071448
# 4               -0.551827                        -0.420502
# ...                   ...                              ...
# 66994            0.149480                        -0.562490
# 66995            0.194876                         0.242109
# 66996           -0.370845                        -0.207520
# 66997           -0.559368                        -0.444166
# 66998           -0.272058                        -0.523443
#
#        Planned Maintanence(MW)  Forced Maintanence(MW)  Other Reasons(MW)  \
# 0                    -0.316747               -0.391646          -0.356442
# 1                    -0.316747               -0.467793          -0.356442
# ...

# %%
y_test
# Out:
# 0         1.01
# 1         0.00
# 2         1.30
# 3        21.70
# 4         0.00
#          ...
# 66994    30.80
# 66995    14.77
# 66996     5.37
# 66997     0.00
# 66998    20.84
# Name: Actual (MW), Length: 66999, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import SGDRegressor
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import ExtraTreesRegressor

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
print(lr.score(X_train, y_train))
print(lr.score(X_test, y_test))
# Out:
# 0.9999999999257838
# 0.999789526250394

# %%
sgd = SGDRegressor()
sgd.fit(X_train, y_train)
print(sgd.score(X_train, y_train))
print(sgd.score(X_test, y_test))
# Out:
# 0.9999997532056847
# 0.9997866947883227

# %%
ls = Lasso()
ls.fit(X_train, y_train)
print(ls.score(X_train, y_train))
print(ls.score(X_test, y_test))
# Out:
# 0.9985274125023605
# 0.9975698516933882

# %%
ri = Ridge()
ri.fit(X_train, y_train)
print(ri.score(X_train, y_train))
print(ri.score(X_test, y_test))
# Out:
# 0.9999999995794112
# 0.9997896795890522

# %%
en = ElasticNet()
en.fit(X_train, y_train)
print(en.score(X_train, y_train))
print(en.score(X_test, y_test))
# Out:
# 0.9250436612990985
# 0.9215771921854385

# %%
knn = KNeighborsRegressor()
knn.fit(X_train, y_train)
print(knn.score(X_train, y_train))
print(knn.score(X_test, y_test))
# Out:
# 0.9986623191852066
# 0.9979049383819371

# %%
dtr = DecisionTreeRegressor()
dtr.fit(X_train, y_train)
print(dtr.score(X_train, y_train))
print(dtr.score(X_test, y_test))
# Out:
# 0.9999999999995143
# 0.9990063102908902

# %%
rfr = RandomForestRegressor()
rfr.fit(X_train, y_train)
print(rfr.score(X_train, y_train))
print(rfr.score(X_test, y_test))
# Out:
# 0.9999719761102809
# 0.9992633314481579

# %%
abr = AdaBoostRegressor()
abr.fit(X_train, y_train)
print(abr.score(X_train, y_train))
print(abr.score(X_test, y_test))
# Out:
# 0.7764507630125962
# 0.7829388762659294

# %%
gbr = GradientBoostingRegressor()
gbr.fit(X_train, y_train)
print(gbr.score(X_train, y_train))
print(gbr.score(X_test, y_test))
# Out:
# 0.9989487678671352
# 0.9982784523643656

# %%
etr = ExtraTreesRegressor()
etr.fit(X_train, y_train)
print(etr.score(X_train, y_train))
print(etr.score(X_test, y_test))
# Out:
# 0.9999999999992215
# 0.9993632876087246

# %%
X_train.shape
# Out:
# (267995, 8)

# %%
y_train.shape
# Out:
# (267995,)

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
params = {'alpha': [0.5,0.6,0.7,0.8,0.9,1.0], 'l1_ratio': [0.5,0.6,0.7,0.8,0.9,1.0], 'tol': [0.1,0.01,0.001,0.0001,0.00001],}

# %%
gscv = GridSearchCV(en, params)

# %%
gscv.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=ElasticNet(),
#              param_grid={'alpha': [0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
#                          'l1_ratio': [0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
#                          'tol': [0.1, 0.01, 0.001, 0.0001, 1e-05]})

# %%
gscv.best_params_
# Out:
# {'alpha': 0.5, 'l1_ratio': 1.0, 'tol': 1e-05}

# %%
gscv.best_score_
# Out:
# 0.9996317180852847

# %%
final_model = ElasticNet(alpha= 0.5, l1_ratio= 1.0, tol= 1e-05)

# %%
final_model.fit(X_train, y_train)
# Out:
# ElasticNet(alpha=0.5, l1_ratio=1.0, tol=1e-05)

# %%
final_model.score(X_test, y_test)
# Out:
# 0.9990403219940138

# %%
final_model.coef_
# Out:
# array([ 0.        ,  0.        ,  0.        ,  0.        ,  0.        ,
#        37.32946225,  9.23395189,  0.        ])

# %%
final_model.intercept_
# Out:
# 19.67973499505587
