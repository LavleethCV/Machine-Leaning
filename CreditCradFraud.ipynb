# %%
import pandas as pd

# %%
data = pd.read_csv('F:/Lavi/Python Course/creditcard.csv')

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
data.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 261403  159998.0  1.724657 -0.106982  0.157860  3.956417 -0.567248  0.250016
# 261404  159998.0 -0.116710  0.622664  0.226647 -1.135911  0.791377 -0.669894
# 261405  160000.0  1.985257 -0.382365 -0.280022  0.494186 -0.721312 -0.528243
# 261406  160001.0 -0.895792  1.271062 -1.315209 -1.293758  1.064260 -1.087220
# 261407  160001.0  2.037399 -1.871314 -0.035755 -1.523020 -1.876304  0.075325
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 261403 -0.557382  0.192135  0.018389  ...  0.248580  0.590834  0.099424
# 261404  0.959207 -0.012747 -0.200576  ... -0.119183 -0.383198  0.080221
# 261405 -0.574594 -0.077543  1.421329  ...  0.188784  0.823228  0.096345
# 261406  1.296419  0.054068 -0.103692  ...  0.207277  0.871975 -0.097011
# 261407 -1.708434  0.060397 -0.991514  ...       NaN       NaN       NaN
#
#              V24       V25       V26       V27       V28  Amount  Class
# 261403 -0.083214 -0.266593  0.087290 -0.009315 -0.023482   80.05    0.0
# 261404 -0.433651 -1.079465 -0.044587  0.142399  0.205543    1.29    0.0
# 261405 -0.074478 -0.064417 -0.207358  0.044080 -0.036908    9.99    0.0
# 261406  0.712642 -0.264557  0.027453  0.300886  0.125450   15.41    0.0
# 261407       NaN       NaN       NaN       NaN       NaN     NaN    NaN
#
# [5 rows x 31 columns]

# %%
data.shape
# Out:
# (261408, 31)

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
data['Class'].unique()
# Out:
# array([ 0.,  1., nan])

# %%
data['Class'].value_counts()
# Out:
# 0.0    260935
# 1.0       472
# Name: Class, dtype: int64

# %%
data.info
# Out:
# <bound method DataFrame.info of             Time        V1        V2        V3        V4        V5        V6  \
# 0            0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1            0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2            1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3            1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4            2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...          ...       ...       ...       ...       ...       ...       ...
# 261403  159998.0  1.724657 -0.106982  0.157860  3.956417 -0.567248  0.250016
# 261404  159998.0 -0.116710  0.622664  0.226647 -1.135911  0.791377 -0.669894
# 261405  160000.0  1.985257 -0.382365 -0.280022  0.494186 -0.721312 -0.528243
# 261406  160001.0 -0.895792  1.271062 -1.315209 -1.293758  1.064260 -1.087220
# 261407  160001.0  2.037399 -1.871314 -0.035755 -1.523020 -1.876304  0.075325
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 0       0.239599  0.098698  0.363787  ... -0.018307  0.277838 -0.110474
# 1      -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288
# 2       0.791461  0.247676 -1.514654  ...  0.247998  0.771679  0.909412
# 3       0.237609  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321
# 4       0.592941 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458
# ...          ...       ...       ...  ...       ...       ...       ...
# 261403 -0.557382  0.192135  0.018389  ...  0.248580  0.590834  0.099424
# 261404  0.959207 -0.012747 -0.200576  ... -0.119183 -0.383198  0.080221
# 261405 -0.574594 -0.077543  1.421329  ...  0.188784  0.823228  0.096345
# 261406  1.296419  0.054068 -0.103692  ...  0.207277  0.871975 -0.097011
# 261407 -1.708434  0.060397 -0.991514  ...       NaN       NaN       NaN
#
#              V24       V25       V26       V27       V28  Amount  Class
# 0       0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62    0.0
# 1      -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69    0.0
# 2      -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3      -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50    0.0
# 4       0.141267 -0.206010  0.502292  0.219422  0.215153   69.99    0.0
# ...          ...       ...       ...       ...       ...     ...    ...
# 261403 -0.083214 -0.266593  0.087290 -0.009315 -0.023482   80.05    0.0
# 261404 -0.433651 -1.079465 -0.044587  0.142399  0.205543    1.29    0.0
# 261405 -0.074478 -0.064417 -0.207358  0.044080 -0.036908    9.99    0.0
# 261406  0.712642 -0.264557  0.027453  0.300886  0.125450   15.41    0.0
# 261407       NaN       NaN       NaN       NaN       NaN     NaN    NaN
#
# [261408 rows x 31 columns]>

# %%
data.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  261408.000000  261408.000000  261408.000000  261408.000000
# mean    88468.339959      -0.019714      -0.016479       0.065663
# std     44336.878816       1.957101       1.660061       1.508726
# min         0.000000     -56.407510     -72.715728     -33.680984
# 25%     51542.000000      -0.927896      -0.608960      -0.780364
# 50%     79412.000000       0.010702       0.059551       0.259821
# 75%    131341.000000       1.282537       0.785382       1.076735
# max    160001.000000       2.454930      22.057729       9.382558
#
#                   V4             V5             V6             V7  \
# count  261408.000000  261408.000000  261408.000000  261408.000000
# mean        0.015061      -0.025850       0.011847      -0.011680
# std         1.415063       1.369857       1.324961       1.222973
# min        -5.683171     -42.147898     -26.160506     -43.557242
# 25%        -0.842316      -0.717028      -0.755623      -0.562317
# 50%         0.002506      -0.082466      -0.258379       0.026516
# 75%         0.776174       0.580853       0.413905       0.554617
# max        16.875344      34.801666      22.529298      36.877368
#
#                   V8             V9  ...            V21            V22  \
# count  261408.000000  261408.000000  ...  261407.000000  261407.000000
# mean        0.000777       0.000250  ...      -0.000551      -0.006341
# std         1.194840       1.107244  ...       0.738235       0.720084
# min       -73.216718     -13.434066  ...     -34.830382     -10.933144
# 25%        -0.204268      -0.651622  ...      -0.225998      -0.536493
# 50%         0.026326      -0.055565  ...      -0.030125       0.003028
# 75%         0.328703       0.604144  ...       0.180817       0.510090
# max        20.007208      15.594995  ...      27.202839      10.503090
#
#                  V23            V24            V25            V26  \
# count  261407.000000  261407.000000  261407.000000  261407.000000
# mean       -0.003579       0.001084       0.013542       0.001251
# std         0.631148       0.605911       0.517013       0.483942
# min       -44.807735      -2.836627     -10.295397      -2.604551
# 25%        -0.163812      -0.351188      -0.300885      -0.328522
# 50%        -0.015651       0.043932       0.039439      -0.056823
# 75%         0.140304       0.435120       0.359860       0.245337
# max        22.528412       4.022866       7.519589       3.517346
#
#                  V27            V28         Amount          Class
# count  261407.000000  261407.000000  261407.000000  261407.000000
# mean       -0.000562       0.000636      89.947150       0.001806
# std         0.400374       0.329994     249.260194       0.042454
# min       -22.565679     -11.710896       0.000000       0.000000
# 25%        -0.070686      -0.051407       5.990000       0.000000
# 50%         0.001824       0.012935      22.810000       0.000000
# 75%         0.089396       0.077749      79.000000       0.000000
# max        12.152401      33.847808   19656.530000       1.000000
#
# [8 rows x 31 columns]

# %%
data.describe().round(2)
# Out:
#             Time         V1         V2         V3         V4         V5  \
# count  261408.00  261408.00  261408.00  261408.00  261408.00  261408.00
# mean    88468.34      -0.02      -0.02       0.07       0.02      -0.03
# std     44336.88       1.96       1.66       1.51       1.42       1.37
# min         0.00     -56.41     -72.72     -33.68      -5.68     -42.15
# 25%     51542.00      -0.93      -0.61      -0.78      -0.84      -0.72
# 50%     79412.00       0.01       0.06       0.26       0.00      -0.08
# 75%    131341.00       1.28       0.79       1.08       0.78       0.58
# max    160001.00       2.45      22.06       9.38      16.88      34.80
#
#               V6         V7         V8         V9  ...        V21        V22  \
# count  261408.00  261408.00  261408.00  261408.00  ...  261407.00  261407.00
# mean        0.01      -0.01       0.00       0.00  ...      -0.00      -0.01
# std         1.32       1.22       1.19       1.11  ...       0.74       0.72
# min       -26.16     -43.56     -73.22     -13.43  ...     -34.83     -10.93
# 25%        -0.76      -0.56      -0.20      -0.65  ...      -0.23      -0.54
# 50%        -0.26       0.03       0.03      -0.06  ...      -0.03       0.00
# 75%         0.41       0.55       0.33       0.60  ...       0.18       0.51
# max        22.53      36.88      20.01      15.59  ...      27.20      10.50
#
#              V23        V24        V25        V26        V27        V28  \
# count  261407.00  261407.00  261407.00  261407.00  261407.00  261407.00
# mean       -0.00       0.00       0.01       0.00      -0.00       0.00
# std         0.63       0.61       0.52       0.48       0.40       0.33
# min       -44.81      -2.84     -10.30      -2.60     -22.57     -11.71
# 25%        -0.16      -0.35      -0.30      -0.33      -0.07      -0.05
# 50%        -0.02       0.04       0.04      -0.06       0.00       0.01
# 75%         0.14       0.44       0.36       0.25       0.09       0.08
# max        22.53       4.02       7.52       3.52      12.15      33.85
#
#           Amount      Class
# count  261407.00  261407.00
# mean       89.95       0.00
# std       249.26       0.04
# min         0.00       0.00
# 25%         5.99       0.00
# 50%        22.81       0.00
# 75%        79.00       0.00
# max     19656.53       1.00
#
# [8 rows x 31 columns]

# %%
data.describe().round(2).style.background_gradient()
# Out:
# <style type="text/css">
# #T_f7963_row0_col0, #T_f7963_row0_col1, #T_f7963_row0_col2, #T_f7963_row0_col3, #T_f7963_row0_col4, #T_f7963_row0_col5, #T_f7963_row0_col6, #T_f7963_row0_col7, #T_f7963_row0_col8, #T_f7963_row0_col9, #T_f7963_row0_col10, #T_f7963_row0_col11, #T_f7963_row0_col12, #T_f7963_row0_col13, #T_f7963_row0_col14, #T_f7963_row0_col15, #T_f7963_row0_col16, #T_f7963_row0_col17, #T_f7963_row0_col18, #T_f7963_row0_col19, #T_f7963_row0_col20, #T_f7963_row0_col21, #T_f7963_row0_col22, #T_f7963_row0_col23, #T_f7963_row0_col24, #T_f7963_row0_col25, #T_f7963_row0_col26, #T_f7963_row0_col27, #T_f7963_row0_col28, #T_f7963_row0_col29, #T_f7963_row0_col30 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_f7963_row1_col0 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_f7963_row1_col1, #T_f7963_row1_col2, #T_f7963_row1_col3, #T_f7963_row1_col4, #T_f7963_row1_col5, #T_f7963_row1_col6, #T_f7963_row1_col7, #T_f7963_row1_col8, #T_f7963_row1_col9, #T_f7963_row1_col10, #T_f7963_row1_col11, #T_f7963_row1_col12, #T_f7963_row1_col13, #T_f7963_row1_col14, #T_f7963_row1_col15, #T_f7963_row1_col16, #T_f7963_row1_col17, #T_f7963_row1_col18, #T_f7963_row1_col19, #T_f7963_row1_col20, #T_f7963_row1_col21, #T_f7963_row1_col22, #T_f7963_row1_col23, #T_f7963_row1_col24, #T_f7963_row1_col25, #T_f7963_row1_col26, #T_f7963_row1_col27, #T_f7963_row1_col28, #T_f7963_row1_col29, #T_f7963_row1_col30, #T_f7963_row2_col1, #T_f7963_row2_col2, #T_f7963_row2_col3, #T_f7963_row2_col4, #T_f7963_row2_col5, #T_f7963_row2_col6, #T_f7963_row2_col7, #T_f7963_row2_col8, #T_f7963_row2_col9, #T_f7963_row2_col10, #T_f7963_row2_col11, #T_f7963_row2_col12, #T_f7963_row2_col13, #T_f7963_row2_col14, #T_f7963_row2_col15, #T_f7963_row2_col16, #T_f7963_row2_col17, #T_f7963_row2_col18, #T_f7963_row2_col19, #T_f7963_row2_col20, #T_f7963_row2_col21, #T_f7963_row2_col22, #T_f7963_row2_col23, #T_f7963_row2_col24, #T_f7963_row2_col25, #T_f7963_row2_col26, #T_f7963_row2_col27, #T_f7963_row2_col28, #T_f7963_row2_col29, #T_f7963_row2_col30, #T_f7963_row3_col0, #T_f7963_row3_col1, #T_f7963_row3_col2, #T_f7963_row3_col3, #T_f7963_row3_col4, #T_f7963_row3_col5, #T_f7963_row3_col6, #T_f7963_row3_col7, #T_f7963_row3_col8, #T_f7963_row3_col9, #T_f7963_row3_col10, #T_f7963_row3_col11, #T_f7963_row3_col12, #T_f7963_row3_col13, #T_f7963_row3_col14, #T_f7963_row3_col15, #T_f7963_row3_col16, #T_f7963_row3_col17, #T_f7963_row3_col18, #T_f7963_row3_col19, #T_f7963_row3_col20, #T_f7963_row3_col21, #T_f7963_row3_col22, #T_f7963_row3_col23, #T_f7963_row3_col24, #T_f7963_row3_col25, #T_f7963_row3_col26, #T_f7963_row3_col27, #T_f7963_row3_col28, #T_f7963_row3_col29, #T_f7963_row3_col30, #T_f7963_row4_col1, #T_f7963_row4_col2, #T_f7963_row4_col3, #T_f7963_row4_col4, #T_f7963_row4_col5, #T_f7963_row4_col6, #T_f7963_row4_col7, #T_f7963_row4_col8, #T_f7963_row4_col9, #T_f7963_row4_col10, #T_f7963_row4_col11, #T_f7963_row4_col12, #T_f7963_row4_col13, #T_f7963_row4_col14, #T_f7963_row4_col15, #T_f7963_row4_col16, #T_f7963_row4_col17, #T_f7963_row4_col18, #T_f7963_row4_col19, #T_f7963_row4_col20, #T_f7963_row4_col21, #T_f7963_row4_col22, #T_f7963_row4_col23, #T_f7963_row4_col24, #T_f7963_row4_col25, #T_f7963_row4_col26, #T_f7963_row4_col27, #T_f7963_row4_col28, #T_f7963_row4_col29, #T_f7963_row4_col30, #T_f7963_row5_col1, #T_f7963_row5_col2, #T_f7963_row5_col3, #T_f7963_row5_col4, #T_f7963_row5_col5, #T_f7963_row5_col6, #T_f7963_row5_col7, #T_f7963_row5_col8, #T_f7963_row5_col9, #T_f7963_row5_col10, #T_f7963_row5_col11, #T_f7963_row5_col12, #T_f7963_row5_col13, #T_f7963_row5_col14, #T_f7963_row5_col15, #T_f7963_row5_col16, #T_f7963_row5_col17, #T_f7963_row5_col18, #T_f7963_row5_col19, #T_f7963_row5_col20, #T_f7963_row5_col21, #T_f7963_row5_col22, #T_f7963_row5_col23, #T_f7963_row5_col24, #T_f7963_row5_col25, #T_f7963_row5_col26, #T_f7963_row5_col27, #T_f7963_row5_col28, #T_f7963_row5_col29, #T_f7963_row5_col30, #T_f7963_row6_col1, #T_f7963_row6_col2, #T_f7963_row6_col3, #T_f7963_row6_col4, #T_f7963_row6_col5, #T_f7963_row6_col6, #T_f7963_row6_col7, #T_f7963_row6_col8, #T_f7963_row6_col9, #T_f7963_row6_col10, #T_f7963_row6_col11, #T_f7963_row6_col12, #T_f7963_row6_col13, #T_f7963_row6_col14, #T_f7963_row6_col15, #T_f7963_row6_col16, #T_f7963_row6_col17, #T_f7963_row6_col18, #T_f7963_row6_col19, #T_f7963_row6_col20, #T_f7963_row6_col21, #T_f7963_row6_col22, #T_f7963_row6_col23, #T_f7963_row6_col24, #T_f7963_row6_col25, #T_f7963_row6_col26, #T_f7963_row6_col27, #T_f7963_row6_col28, #T_f7963_row6_col29, #T_f7963_row6_col30, #T_f7963_row7_col1, #T_f7963_row7_col2, #T_f7963_row7_col3, #T_f7963_row7_col4, #T_f7963_row7_col5, #T_f7963_row7_col6, #T_f7963_row7_col7, #T_f7963_row7_col8, #T_f7963_row7_col9, #T_f7963_row7_col10, #T_f7963_row7_col11, #T_f7963_row7_col12, #T_f7963_ro ...
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_f7963_row2_col0 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_f7963_row4_col0 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_f7963_row5_col0 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_f7963_row6_col0 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_f7963_row7_col0 {
#   background-color: #3d93c2;
#   color: #f1f1f1;
# }
# #T_f7963_row7_col29 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# </style>
# <table id="T_f7963">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f7963_level0_col0" class="col_heading level0 col0" >Time</th>
#       <th id="T_f7963_level0_col1" class="col_heading level0 col1" >V1</th>
#       <th id="T_f7963_level0_col2" class="col_heading level0 col2" >V2</th>
#       <th id="T_f7963_level0_col3" class="col_heading level0 col3" >V3</th>
#       <th id="T_f7963_level0_col4" class="col_heading level0 col4" >V4</th>
#       <th id="T_f7963_level0_col5" class="col_heading level0 col5" >V5</th>
#       <th id="T_f7963_level0_col6" class="col_heading level0 col6" >V6</th>
#       <th id="T_f7963_level0_col7" class="col_heading level0 col7" >V7</th>
#       <th id="T_f7963_level0_col8" class="col_heading level0 col8" >V8</th>
#       <th id="T_f7963_level0_col9" class="col_heading level0 col9" >V9</th>
#       <th id="T_f7963_level0_col10" class="col_heading level0 col10" >V10</th>
#       <th id="T_f7963_level0_col11" class="col_heading level0 col11" >V11</th>
#       <th id="T_f7963_level0_col12" class="col_heading level0 col12" >V12</th>
#       <th id="T_f7963_level0_col13" class="col_heading level0 col13" >V13</th>
#       <th id="T_f7963_level0_col14" class="col_heading level0 col14" >V14</th>
#       <th id="T_f7963_level0_col15" class="col_heading level0 col15" >V15</th>
#       <th id="T_f7963_level0_col16" class="col_heading level0 col16" >V16</th>
#       <th id="T_f7963_level0_col17" class="col_heading level0 col17" >V17</th>
#       <th id="T_f7963_level0_col18" class="col_heading level0 col18" >V18</th>
#       <th id="T_f7963_level0_col19" class="col_heading level0 col19" >V19</th>
#       <th id="T_f7963_level0_col20" class="col_heading level0 col20" >V20</th>
#       <th id="T_f7963_level0_col21" class="col_heading level0 col21" >V21</th>
#       <th id="T_f7963_level0_col22" class="col_heading level0 col22" >V22</th>
#       <th id="T_f7963_level0_col23" class="col_heading level0 col23" >V23</th>
#       <th id="T_f7963_level0_col24" class="col_heading level0 col24" >V24</th>
#       <th id="T_f7963_level0_col25" class="col_heading level0 col25" >V25</th>
#       <th id="T_f7963_level0_col26" class="col_heading level0 col26" >V26</th>
#       <th id="T_f7963_level0_col27" class="col_heading level0 col27" >V27</th>
#       <th id="T_f7963_level0_col28" class="col_heading level0 col28" >V28</th>
#       <th id="T_f7963_level0_col29" class=

# %%
data.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class     float64
# dtype: object

# %%
data.duplicated().sum()
# Out:
# 961

# %%
data = data.dropna()

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 261402  159997.0  1.963643 -0.197213 -0.242931  1.319373 -0.632146 -0.468105
# 261403  159998.0  1.724657 -0.106982  0.157860  3.956417 -0.567248  0.250016
# 261404  159998.0 -0.116710  0.622664  0.226647 -1.135911  0.791377 -0.669894
# 261405  160000.0  1.985257 -0.382365 -0.280022  0.494186 -0.721312 -0.528243
# 261406  160001.0 -0.895792  1.271062 -1.315209 -1.293758  1.064260 -1.087220
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 261402 -0.567685  0.026664  1.075990  ...  0.210158  0.730741  0.153845
# 261403 -0.557382  0.192135  0.018389  ...  0.248580  0.590834  0.099424
# 261404  0.959207 -0.012747 -0.200576  ... -0.119183 -0.383198  0.080221
# 261405 -0.574594 -0.077543  1.421329  ...  0.188784  0.823228  0.096345
# 261406  1.296419  0.054068 -0.103692  ...  0.207277  0.871975 -0.097011
#
#              V24       V25       V26       V27       V28  Amount  Class
# 261402 -0.129568 -0.129826 -0.549987  0.053930 -0.034269    1.00    0.0
# 261403 -0.083214 -0.266593  0.087290 -0.009315 -0.023482   80.05    0.0
# 261404 -0.433651 -1.079465 -0.044587  0.142399  0.205543    1.29    0.0
# 261405 -0.074478 -0.064417 -0.207358  0.044080 -0.036908    9.99    0.0
# 261406  0.712642 -0.264557  0.027453  0.300886  0.125450   15.41    0.0
#
# [5 rows x 31 columns]

# %%
data.shape
# Out:
# (261407, 31)

# %%
data.drop_duplicates(inplace= True)
# Out:
# C:\Users\Lavieeth\AppData\Local\Temp\ipykernel_5820\947344984.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop_duplicates(inplace= True)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.shape
# Out:
# (260446, 31)

# %%
X = data.iloc[:, 0:-1]
y= data.iloc[:, -1]

# %%
X.drop('Time', axis = 1, inplace= True)
# Out:
# C:\Users\Lavieeth\AppData\Local\Temp\ipykernel_5820\2938045160.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.drop('Time', axis = 1, inplace= True)

# %%
X.shape
# Out:
# (260446, 29)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=0)

# %%
X_train = pd.DataFrame(X_train)

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()

# %%
X_train = ss.fit_transform(X_train)

# %%
X_train.shape
# Out:
# (182312, 29)

# %%
type(X_train)
# Out:
# numpy.ndarray

# %%
X_train = pd.DataFrame(X_train)

# %%
X_train.describe()
# Out:
#                  0             1             2             3             4   \
# count  1.823120e+05  1.823120e+05  1.823120e+05  1.823120e+05  1.823120e+05
# mean   2.650232e-17  4.706110e-18 -1.344603e-18  2.209826e-17 -6.079944e-18
# std    1.000003e+00  1.000003e+00  1.000003e+00  1.000003e+00  1.000003e+00
# min   -2.900118e+01 -4.393759e+01 -2.198826e+01 -4.028206e+00 -3.067217e+01
# 25%   -4.690908e-01 -3.574043e-01 -5.637946e-01 -6.059896e-01 -5.026256e-01
# 50%    1.464172e-02  4.763235e-02  1.271342e-01 -9.460071e-03 -4.269062e-02
# 75%    6.669600e-01  4.852218e-01  6.713452e-01  5.363760e-01  4.419451e-01
# max    1.269390e+00  1.334421e+01  6.201878e+00  1.191748e+01  2.535682e+01
#
#                  5             6             7             8             9   \
# count  1.823120e+05  1.823120e+05  1.823120e+05  1.823120e+05  1.823120e+05
# mean   3.117920e-19  1.500499e-17  4.676880e-19  2.611258e-18  4.910724e-18
# std    1.000003e+00  1.000003e+00  1.000003e+00  1.000003e+00  1.000003e+00
# min   -1.968789e+01 -3.554587e+01 -6.146240e+01 -1.216585e+01 -2.271643e+01
# 25%   -5.751970e-01 -4.489182e-01 -1.702824e-01 -5.898521e-01 -4.890173e-01
# 50%   -2.038955e-01  3.108776e-02  2.372023e-02 -5.181434e-02 -8.236110e-02
# 75%    3.021500e-01  4.612929e-01  2.763008e-01  5.456915e-01  4.252525e-01
# max    1.694009e+01  2.994700e+01  1.679815e+01  1.412238e+01  2.194092e+01
#
#        ...            19            20            21            22  \
# count  ...  1.823120e+05  1.823120e+05  1.823120e+05  1.823120e+05
# mean   ...  5.758408e-18  1.305629e-18 -1.952597e-17 -2.806128e-18
# std    ...  1.000003e+00  1.000003e+00  1.000003e+00  1.000003e+00
# min    ... -3.241572e+01 -4.782361e+01 -1.518059e+01 -7.114969e+01
# 25%    ... -2.728730e-01 -3.079279e-01 -7.383357e-01 -2.544462e-01
# 50%    ... -8.017692e-02 -3.860611e-02  1.351488e-02 -1.979719e-02
# 75%    ...  1.733578e-01  2.517348e-01  7.184267e-01  2.275955e-01
# max    ...  5.065100e+01  3.105621e+01  1.460016e+01  3.053904e+01
#
#                  23            24            25            26            27  \
# count  1.823120e+05  1.823120e+05  1.823120e+05  1.823120e+05  1.823120e+05
# mean   1.747984e-17 -8.126078e-18  1.208194e-18  2.728180e-18 -4.443036e-18
# std    1.000003e+00  1.000003e+00  1.000003e+00  1.000003e+00  1.000003e+00
# min   -4.656091e+00 -1.994532e+01 -5.389256e+00 -5.689665e+01 -3.660973e+01
# 25%   -5.822727e-01 -6.079772e-01 -6.818678e-01 -1.789944e-01 -1.616060e-01
# 50%    6.942088e-02  5.039165e-02 -1.208217e-01  3.526294e-03  3.911459e-02
# 75%    7.159995e-01  6.705941e-01  5.051529e-01  2.245851e-01  2.415575e-01
# max    6.624957e+00  1.130047e+01  7.269876e+00  2.807637e+01  1.058088e+02
#
#                  28
# count  1.823120e+05
# mean   8.067617e-18
# std    1.000003e+00
# min   -3.579246e-01
# 25%   -3.341380e-01
# 50%   -2.667891e-01
# 75%   -4.399381e-02
# max    7.769899e+01
#
# [8 rows x 29 columns]

# %%
X_test = ss.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
import time

# %%
start = time.time()
lr.fit(X_train, y_train)
print(lr.score(X_train, y_train))
print(lr.score(X_test, y_test))
end = time.time()
print(end - start)
# Out:
# 0.9991717495282811
# 0.999065707630481
# 2.087648868560791

# %%
from sklearn.metrics import f1_score

# %%
y_pred = lr.predict(X_test)
print(f1_score(y_test, y_pred))
# Out:
# 0.6368159203980099

# %%
from sklearn.metrics import plot_confusion_matrix

# %%
plot_confusion_matrix(lr, X_test, y_test)
# Out:
# c:\Users\Lavieeth\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
from sklearn.svm import SVC

# %%
svc = SVC()

# %%
start = time.time()
svc.fit(X_train, y_train)
print(svc.score(X_train, y_train))
print(svc.score(X_test, y_test))
end = time.time()
print(end - start)
# Out:
# 0.9996983193646057
# 0.9993216781426779
# 1416.7367396354675

# %%
y_pred = svc.predict(X_test)
print(f1_score(y_test, y_pred))

# %%
plot_confusion_matrix(svc, X_test, y_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()

# %%
start = time.time()
knn.fit(X_train, y_train)
print(knn.score(X_train, y_train))
print(knn.score(X_test, y_test))
end = time.time()
print(end - start)
# Out:
# 0.9995611918030629
# 0.9993728722451174
# 1006.2606987953186

# %%
y_pred = knn.predict(X_test)
print(f1_score(y_test, y_pred))
# Out:
# 0.7822222222222222

# %%
plot_confusion_matrix(knn, X_test, y_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier()

# %%
start = time.time()
dtc.fit(X_train, y_train)
print(dtc.score(X_train, y_train))
print(dtc.score(X_test, y_test))
end = time.time()
print(end - start)
# Out:
# 1.0
# 0.9991808943609696
# 19.524776220321655

# %%
y_pred = dtc.predict(X_test)
print(f1_score(y_test, y_pred))
# Out:
# 0.7377049180327869

# %%
plot_confusion_matrix(dtc, X_test, y_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
dtc.feature_importances_
# Out:
# array([0.0083935 , 0.        , 0.01919518, 0.01321937, 0.        ,
#        0.00333512, 0.00909321, 0.        , 0.00491677, 0.05348619,
#        0.00362527, 0.04791801, 0.01326205, 0.10425821, 0.00614683,
#        0.01769485, 0.54313073, 0.00273154, 0.01685825, 0.00998806,
#        0.01537711, 0.00307267, 0.00682884, 0.01036574, 0.00585708,
#        0.02842722, 0.04530304, 0.00114527, 0.0063699 ])

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=10)

# %%
start = time.time()
rfc.fit(X_train, y_train)
print(rfc.score(X_train, y_train))
print(rfc.score(X_test, y_test))
end = time.time()
print(end - start)
# Out:
# 0.9999177234630743
# 0.999398469296337
# 17.52908706665039

# %%
y_pred = rfc.predict(X_test)
print(f1_score(y_test, y_pred))
# Out:
# 0.7853881278538813

# %%
plot_confusion_matrix(rfc, X_test, y_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB()

# %%
start = time.time()
gnb.fit(X_train, y_train)
print(gnb.score(X_train, y_train))
print(gnb.score(X_test, y_test))
end = time.time()
print(end - start)
# Out:
# 0.9775878713414367
# 0.978280902040085
# 0.26640939712524414

# %%
y_pred = gnb.predict(X_test)
print(f1_score(y_test, y_pred))

# %%
plot_confusion_matrix(gnb, X_test, y_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
gnb.get_params(deep= True)
# Out:
# {'priors': None, 'var_smoothing': 1e-09}

# %%
from sklearn.linear_model import SGDClassifier

# %%
sgd = SGDClassifier()

# %%
start = time.time()
sgd.fit(X_train, y_train)
print(sgd.score(X_train, y_train))
print(sgd.score(X_test, y_test))
end = time.time()
print(end - start)
# Out:
# 0.999116898503664
# 0.9990145135280416
# 0.645484447479248

# %%
y_pred = sgd.predict(X_test)
print(f1_score(y_test, y_pred))
# Out:
# 0.6051282051282051

# %%
plot_confusion_matrix(sgd, X_test, y_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
param_dist = {'max_depth': [3, 7, 9], 'min_samples_leaf': [2, 5, 7], 'criterion': ['entropy', 'gini']}

# %%
rscv = RandomizedSearchCV(rfc, param_dist, n_iter= 6, cv= 3)

# %%
rscv.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=3, estimator=RandomForestClassifier(n_estimators=10),
#                    n_iter=6,
#                    param_distributions={'criterion': ['entropy', 'gini'],
#                                         'max_depth': [3, 7, 9],
#                                         'min_samples_leaf': [2, 5, 7]})

# %%
rscv.best_params_
# Out:
# {'min_samples_leaf': 5, 'max_depth': 7, 'criterion': 'entropy'}

# %%
type(y_train)
# Out:
# pandas.core.series.Series

# %%
y_train.shape
# Out:
# (182312,)

# %%
y_train.unique()
# Out:
# array([0., 1.])

# %%
from sklearn.naive_bayes import BernoulliNB

# %%
bnb = BernoulliNB()

# %%
start = time.time()
bnb.fit(X_train, y_train)
print(bnb.score(X_train, y_train))
print(bnb.score(X_test, y_test))
end = time.time()
print(end - start)
# Out:
# 0.9991443240159726
# 0.9991169017329203
# 0.5138366222381592

# %%
y_pred = bnb.predict(X_test)
print(f1_score(y_test, y_pred))
# Out:
# 0.6790697674418605

# %%
plot_confusion_matrix(bnb, X_test, y_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
