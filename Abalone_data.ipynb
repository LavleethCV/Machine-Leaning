# %%
import pandas as pd

# %%
column_names = ['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight', 'Viscera weight', 'Shell weight', 'Rings']

# %%
data = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/abalone/abalone.data', names = column_names)

#columns (pd.DataFrame)
#names (pd.read_csv)

# %%
data.head(20)
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    M   0.455     0.365   0.095        0.5140          0.2245
# 1    M   0.350     0.265   0.090        0.2255          0.0995
# 2    F   0.530     0.420   0.135        0.6770          0.2565
# 3    M   0.440     0.365   0.125        0.5160          0.2155
# 4    I   0.330     0.255   0.080        0.2050          0.0895
# 5    I   0.425     0.300   0.095        0.3515          0.1410
# 6    F   0.530     0.415   0.150        0.7775          0.2370
# 7    F   0.545     0.425   0.125        0.7680          0.2940
# 8    M   0.475     0.370   0.125        0.5095          0.2165
# 9    F   0.550     0.440   0.150        0.8945          0.3145
# 10   F   0.525     0.380   0.140        0.6065          0.1940
# 11   M   0.430     0.350   0.110        0.4060          0.1675
# 12   M   0.490     0.380   0.135        0.5415          0.2175
# 13   F   0.535     0.405   0.145        0.6845          0.2725
# ...

# %%
data.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
data['Total_weight'] = data.iloc[:, [4,5,6,7]].sum(axis = 1)

# %%
data
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings  Total_weight
# 0             0.1010        0.1500     15        0.9895
# 1             0.0485        0.0700      7        0.4435
# ...

# %%
data.drop(columns= ['Whole weight',	'Shucked weight',	'Viscera weight',	'Shell weight'])
# Out:
#      Sex  Length  Diameter  Height  Rings  Total_weight
# 0      M   0.455     0.365   0.095     15        0.9895
# 1      M   0.350     0.265   0.090      7        0.4435
# 2      F   0.530     0.420   0.135      9        1.2850
# 3      M   0.440     0.365   0.125     10        1.0005
# 4      I   0.330     0.255   0.080      7        0.3890
# ...   ..     ...       ...     ...    ...           ...
# 4172   F   0.565     0.450   0.165     11        1.7450
# 4173   M   0.590     0.440   0.135     10        1.8800
# 4174   M   0.600     0.475   0.205      9        2.2970
# 4175   F   0.625     0.485   0.150     10        2.1825
# 4176   M   0.710     0.555   0.195     12        3.7655
#
# [4177 rows x 6 columns]

# %%
data
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings  Total_weight
# 0             0.1010        0.1500     15        0.9895
# 1             0.0485        0.0700      7        0.4435
# ...

# %%
data = data.drop(columns= ['Whole weight',	'Shucked weight',	'Viscera weight',	'Shell weight'])

# %%
data
# Out:
#      Sex  Length  Diameter  Height  Rings  Total_weight
# 0      M   0.455     0.365   0.095     15        0.9895
# 1      M   0.350     0.265   0.090      7        0.4435
# 2      F   0.530     0.420   0.135      9        1.2850
# 3      M   0.440     0.365   0.125     10        1.0005
# 4      I   0.330     0.255   0.080      7        0.3890
# ...   ..     ...       ...     ...    ...           ...
# 4172   F   0.565     0.450   0.165     11        1.7450
# 4173   M   0.590     0.440   0.135     10        1.8800
# 4174   M   0.600     0.475   0.205      9        2.2970
# 4175   F   0.625     0.485   0.150     10        2.1825
# 4176   M   0.710     0.555   0.195     12        3.7655
#
# [4177 rows x 6 columns]

# %%
data.dtypes
# Out:
# Sex              object
# Length          float64
# Diameter        float64
# Height          float64
# Rings             int64
# Total_weight    float64
# dtype: object

# %%
data.shape
# Out:
# (4177, 6)

# %%
data = pd.get_dummies(data, columns=['Sex'])

# %%
data.shape
# Out:
# (4177, 8)

# %%
data.head()
# Out:
#    Length  Diameter  Height  Rings  Total_weight  Sex_F  Sex_I  Sex_M
# 0   0.455     0.365   0.095     15        0.9895      0      0      1
# 1   0.350     0.265   0.090      7        0.4435      0      0      1
# 2   0.530     0.420   0.135      9        1.2850      1      0      0
# 3   0.440     0.365   0.125     10        1.0005      0      0      1
# 4   0.330     0.255   0.080      7        0.3890      0      1      0

# %%
data.describe()
# Out:
#             Length     Diameter       Height        Rings  Total_weight  \
# count  4177.000000  4177.000000  4177.000000  4177.000000   4177.000000
# mean      0.523992     0.407881     0.139516     9.933684      1.607534
# std       0.120093     0.099240     0.041827     3.224169      0.945565
# min       0.075000     0.055000     0.000000     1.000000      0.005000
# 25%       0.450000     0.350000     0.115000     8.000000      0.861000
# 50%       0.545000     0.425000     0.140000     9.000000      1.554500
# 75%       0.615000     0.480000     0.165000    11.000000      2.239000
# max       0.815000     0.650000     1.130000    29.000000      5.466000
#
#              Sex_F        Sex_I        Sex_M
# count  4177.000000  4177.000000  4177.000000
# mean      0.312904     0.321283     0.365813
# std       0.463731     0.467025     0.481715
# min       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000
# ...

# %%
y = data.iloc[:, 3]

# %%
y
# Out:
# 0       15
# 1        7
# 2        9
# 3       10
# 4        7
#         ..
# 4172    11
# 4173    10
# 4174     9
# 4175    10
# 4176    12
# Name: Rings, Length: 4177, dtype: int64

# %%
X = data.iloc[:, [0,1,2,4,5,6,7]]

# %%
X
# Out:
#       Length  Diameter  Height  Total_weight  Sex_F  Sex_I  Sex_M
# 0      0.455     0.365   0.095        0.9895      0      0      1
# 1      0.350     0.265   0.090        0.4435      0      0      1
# 2      0.530     0.420   0.135        1.2850      1      0      0
# 3      0.440     0.365   0.125        1.0005      0      0      1
# 4      0.330     0.255   0.080        0.3890      0      1      0
# ...      ...       ...     ...           ...    ...    ...    ...
# 4172   0.565     0.450   0.165        1.7450      1      0      0
# 4173   0.590     0.440   0.135        1.8800      0      0      1
# 4174   0.600     0.475   0.205        2.2970      0      0      1
# 4175   0.625     0.485   0.150        2.1825      1      0      0
# 4176   0.710     0.555   0.195        3.7655      0      0      1
#
# [4177 rows x 7 columns]

# %%
X.describe()
# Out:
#             Length     Diameter       Height  Total_weight        Sex_F  \
# count  4177.000000  4177.000000  4177.000000   4177.000000  4177.000000
# mean      0.523992     0.407881     0.139516      1.607534     0.312904
# std       0.120093     0.099240     0.041827      0.945565     0.463731
# min       0.075000     0.055000     0.000000      0.005000     0.000000
# 25%       0.450000     0.350000     0.115000      0.861000     0.000000
# 50%       0.545000     0.425000     0.140000      1.554500     0.000000
# 75%       0.615000     0.480000     0.165000      2.239000     1.000000
# max       0.815000     0.650000     1.130000      5.466000     1.000000
#
#              Sex_I        Sex_M
# count  4177.000000  4177.000000
# mean      0.321283     0.365813
# std       0.467025     0.481715
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       0.000000     0.000000
# 75%       1.000000     1.000000
# max       1.000000     1.000000

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size= 0.2, random_state=1)

# %%
X_train.shape
# Out:
# (3341, 7)

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()

# %%
X_train = ss.fit_transform(X_train)

# %%
X_train = pd.DataFrame(X_train)

# %%
X_train.columns = ['Length','Diameter','Height','Total_weight','Sex_F',	'Sex_I','Sex_M']

# %%
X_train
# Out:
#         Length  Diameter    Height  Total_weight    Sex_F     Sex_I     Sex_M
# 0    -0.568635 -0.579140 -0.457631     -0.674332 -0.67558 -0.690188  1.321943
# 1    -2.226410 -2.133887 -1.974904     -1.549076 -0.67558  1.448882 -0.756462
# 2    -0.029858  0.022697 -0.691057     -0.630595 -0.67558  1.448882 -0.756462
# 3     0.799029  0.624535  0.359362      0.273132 -0.67558  1.448882 -0.756462
# 4     0.757585  0.825147  0.359362      0.352176 -0.67558  1.448882 -0.756462
# ...        ...       ...       ...           ...      ...       ...       ...
# 3336  0.135919  0.072850 -0.691057     -0.408747 -0.67558  1.448882 -0.756462
# 3337  0.218808  0.173157 -0.107491     -0.340243 -0.67558  1.448882 -0.756462
# 3338 -1.687633 -1.682509 -1.157910     -1.383086 -0.67558  1.448882 -0.756462
# 3339  0.011586  0.022697 -0.574344     -0.079400  1.48021 -0.690188 -0.756462
# 3340 -1.894855 -1.832969 -1.391337     -1.437889 -0.67558  1.448882 -0.756462
#
# [3341 rows x 7 columns]

# %%
X_test = ss.transform(X_test)

# %%
X_test = pd.DataFrame(X_test)

# %%
X_test.columns = ['Length','Diameter','Height','Total_weight','Sex_F',	'Sex_I','Sex_M']

# %%
X_test
# Out:
#        Length  Diameter    Height  Total_weight    Sex_F     Sex_I     Sex_M
# 0   -0.692968 -0.679447 -0.924484     -0.793424  1.48021 -0.690188 -0.756462
# 1    0.343141  0.273463  0.242649      0.367984 -0.67558 -0.690188  1.321943
# 2   -1.273190 -1.281284 -0.807771     -1.212879 -0.67558 -0.690188  1.321943
# 3    0.467474  0.474075 -0.107491     -0.039352 -0.67558 -0.690188  1.321943
# 4    0.011586 -0.177915 -0.107491     -0.464604  1.48021 -0.690188 -0.756462
# ..        ...       ...       ...           ...      ...       ...       ...
# 831  0.177364  0.123004  0.592789      0.164053 -0.67558  1.448882 -0.756462
# 832  1.296362  1.126066  1.059642      1.369725  1.48021 -0.690188 -0.756462
# 833  0.260252  0.373769  0.826216      0.644108  1.48021 -0.690188 -0.756462
# 834  1.172029  1.226372  0.942929      1.363401  1.48021 -0.690188 -0.756462
# 835  0.633252  0.925454  0.359362      1.033001  1.48021 -0.690188 -0.756462
#
# [836 rows x 7 columns]

# %%
from sklearn.linear_model import LinearRegression, SGDRegressor, Ridge, Lasso, ElasticNet
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

# %%
from sklearn.metrics import f1_score, ConfusionMatrixDisplay

# %%
lr = LinearRegression()
sgd = SGDRegressor(random_state=1)
ri= Ridge(random_state=1)
la = Lasso(random_state=1)
en = ElasticNet(random_state=1)
svr = SVR()
knr = KNeighborsRegressor()
dtr = DecisionTreeRegressor(random_state=1)
rfr = RandomForestRegressor(random_state=1)
gbr = GradientBoostingRegressor(random_state=1)

# %%
lr.fit(X_train, y_train)
sgd.fit(X_train, y_train)
ri.fit(X_train, y_train)
la.fit(X_train, y_train)
en.fit(X_train, y_train)
ri.fit(X_train, y_train)
svr.fit(X_train, y_train)
knr.fit(X_train, y_train)
dtr.fit(X_train, y_train)
rfr.fit(X_train, y_train)
gbr.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(random_state=1)

# %%
M1 = lr.score(X_test, y_test)
M2 = sgd.score(X_test, y_test)
M3 = ri.score(X_test, y_test)
M4 = la.score(X_test, y_test)
M5 = en.score(X_test, y_test)
M6 = svr.score(X_test, y_test)
M7 = knr.score(X_test, y_test)
M8 = dtr.score(X_test, y_test)
M8 = rfr.score(X_test, y_test)
M9 = gbr.score(X_test, y_test)

A_scores = [M1, M2, M3, M4, M5, M6, M7, M8, M9]
A_scores
# Out:
# [0.3593593557708755,
#  0.35379103212191376,
#  0.3599090707640682,
#  0.2371389365061346,
#  0.2976037346467947,
#  0.34886662005048485,
#  0.3268406584935839,
#  0.32678016196787885,
#  0.36742997754482065]

# %%
y_pred_gbr = gbr.predict(X_test)

# %%
y_pred_gbr.round(0)
# Out:
# array([ 9., 11.,  9., 10., 10.,  6., 10., 11., 14.,  8., 12.,  5., 10.,
#        11.,  7., 10., 11., 13., 12., 10., 11., 12.,  7., 13., 10., 11.,
#        13., 11., 12., 12., 10.,  9., 10.,  8.,  7.,  9., 11., 12., 12.,
#        11., 10., 13., 14., 10.,  8., 10., 11., 10., 11., 11., 11., 10.,
#        10.,  5., 12., 10., 10.,  7., 10.,  8., 10.,  9., 12., 10.,  9.,
#         8., 11., 10., 12.,  8., 10., 12.,  6., 10., 10.,  7., 12., 11.,
#        10., 10.,  8., 10., 11., 10., 11., 10., 10.,  9., 11., 10., 10.,
#        10., 10., 11.,  7., 10., 11., 15.,  6., 12.,  9., 11.,  7., 10.,
#        15., 11., 11., 10., 10., 10.,  9., 10.,  8.,  7.,  6., 11.,  8.,
#         7., 11., 11., 10.,  8.,  7., 11., 10., 12., 11., 11.,  8., 12.,
#        10.,  7., 10.,  8., 11.,  8., 11., 12., 10., 11.,  8., 10., 10.,
#        12.,  8., 10., 11., 14., 10., 11., 11.,  7.,  9., 12., 10., 10.,
#        13., 11., 10., 12., 10., 12., 12.,  7.,  8., 10., 12., 13., 10.,
# ...

# %%
from sklearn.model_selection import RandomizedSearchCV
